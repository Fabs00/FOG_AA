# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabs00/FOG_AA/blob/main/Tarea_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tarea en clase

# %% [markdown]
# Cargar conjunto de datos mediante pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/covid.csv")

# %% [markdown]
# Especificar el tipo de datos de cada columna

# %%
df.info()

# %%
df.head()

# %% [markdown]
# Si es necesario, asignar una columna como índice

# %%
df['nuevo_indice'] = range(len(df))
df.set_index('nuevo_indice', inplace=True)

# %%
df.head()

# %% [markdown]
# #Tarea

# %% [markdown]
# Crear, modificar o eliminar columnas

# %%
df_sin_columna = df.drop(columns=['NewDeaths'])
df_sin_columna
# Out:
#                      Country/Region      Continent    Population  TotalCases  \
# nuevo_indice
# 0                               USA  North America  3.311981e+08     5032179
# 1                            Brazil  South America  2.127107e+08     2917562
# 2                             India           Asia  1.381345e+09     2025409
# 3                            Russia         Europe  1.459409e+08      871894
# 4                      South Africa         Africa  5.938157e+07      538184
# ...                             ...            ...           ...         ...
# 204                      Montserrat  North America  4.992000e+03          13
# 205           Caribbean Netherlands  North America  2.624700e+04          13
# 206                Falkland Islands  South America  3.489000e+03          13
# 207                    Vatican City         Europe  8.010000e+02          12
# 208                  Western Sahara         Africa  5.986820e+05          10
#
# ...

# %% [markdown]
# Filtrar registros

# %%
df.tail(10)

# %%
df.head(5)
# Out:
#              Country/Region      Continent    Population  TotalCases  \
# nuevo_indice
# 0                       USA  North America  3.311981e+08     5032179
# 1                    Brazil  South America  2.127107e+08     2917562
# 2                     India           Asia  1.381345e+09     2025409
# 3                    Russia         Europe  1.459409e+08      871894
# 4              South Africa         Africa  5.938157e+07      538184
#
#               NewCases  TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  \
# nuevo_indice
# 0                  NaN     162804.0        NaN       2576668.0           NaN
# 1                  NaN      98644.0        NaN       2047660.0           NaN
# 2                  NaN      41638.0        NaN       1377384.0           NaN
# 3                  NaN      14606.0        NaN        676357.0           NaN
# 4                  NaN       9604.0        NaN        387316.0           NaN
#
# ...

# %% [markdown]
# Crear subconjutos de datos

# %%
subconjunto = df.loc[df["Deaths/1M pop"] > 100, ["Country/Region", "Continent"]]

# %%
subconjunto

# %% [markdown]
# Crear grupos de datos

# %%
grupo = df.groupby("Continent")["TotalCases"].mean()

# %%
grupo
# Out:
# Continent
# Africa                17752.052632
# Asia                  97704.041667
# Australia/Oceania      3622.500000
# Europe                62137.000000
# North America        169120.257143
# South America        324519.500000
# Name: TotalCases, dtype: float64
